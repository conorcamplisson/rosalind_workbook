# %% [markdown]
# # Divide-and-conquer
#
#
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/divide-and-conquer.jpg?v=1526042457">
#
# Rosalind link: [Divide-and-conquer](http://rosalind.info/problems/topics/divide-and-conquer/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Binary Search
#
# Rosalind link: [Binary Search](http://rosalind.info/problems/bins/)

# %%
# TODO

# %% [markdown]
# ### Merge Sort
#
# Rosalind link: [Merge Sort](http://rosalind.info/problems/ms/)

# %%
# TODO
