# %% [markdown]
# # Alignment
#
# Superimposing the symbols of one string over those of another (with gap symbols inserted into the strings) to represent insertions, deletions, and substitutions between the strings.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/alignment.jpg?v=1526042457">
#
# Rosalind link: [Alignment](http://rosalind.info/problems/topics/alignment/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Counting Point Mutations
#
# Rosalind link: [Counting Point Mutations](http://rosalind.info/problems/hamm/)

# %%
# TODO

# %% [markdown]
# ### Transitions and Transversions
#
# Rosalind link: [Transitions and Transversions](http://rosalind.info/problems/tran/)

# %%
# TODO

# %% [markdown]
# ### Creating a Distance Matrix
#
# Rosalind link: [Creating a Distance Matrix](http://rosalind.info/problems/pdst/)

# %%
# TODO

# %% [markdown]
# ### Edit Distance
#
# Rosalind link: [Edit Distance](http://rosalind.info/problems/edit/)

# %%
# TODO

# %% [markdown]
# ### Edit Distance Alignment
#
# Rosalind link: [Edit Distance Alignment](http://rosalind.info/problems/edta/)

# %%
# TODO

# %% [markdown]
# ### Counting Optimal Alignments
#
# Rosalind link: [Counting Optimal Alignments](http://rosalind.info/problems/ctea/)

# %%
# TODO

# %% [markdown]
# ### Global Alignment with Scoring Matrix
#
# Rosalind link: [Global Alignment with Scoring Matrix](http://rosalind.info/problems/glob/)

# %%
# TODO

# %% [markdown]
# ### Global Alignment with Constant Gap Penalty
#
# Rosalind link: [Global Alignment with Constant Gap Penalty](http://rosalind.info/problems/gcon/)

# %%
# TODO

# %% [markdown]
# ### Local Alignment with Scoring Matrix
#
# Rosalind link: [Local Alignment with Scoring Matrix](http://rosalind.info/problems/loca/)

# %%
# TODO

# %% [markdown]
# ### Maximizing the Gap Symbols of an Optimal Alignment
#
# Rosalind link: [Maximizing the Gap Symbols of an Optimal Alignment](http://rosalind.info/problems/mgap/)

# %%
# TODO

# %% [markdown]
# ### Multiple Alignment
#
# Rosalind link: [Multiple Alignment](http://rosalind.info/problems/mult/)

# %%
# TODO

# %% [markdown]
# ### Global Alignment with Scoring Matrix and Affine Gap Penalty
#
# Rosalind link: [Global Alignment with Scoring Matrix and Affine Gap Penalty](http://rosalind.info/problems/gaff/)

# %%
# TODO

# %% [markdown]
# ### Overlap Alignment
#
# Rosalind link: [Overlap Alignment](http://rosalind.info/problems/oap/)

# %%
# TODO

# %% [markdown]
# ### Semiglobal Alignment
#
# Rosalind link: [Semiglobal Alignment](http://rosalind.info/problems/smgb/)

# %%
# TODO

# %% [markdown]
# ### Local Alignment with Affine Gap Penalty
#
# Rosalind link: [Local Alignment with Affine Gap Penalty](http://rosalind.info/problems/laff/)

# %%
# TODO

# %% [markdown]
# ### Isolating Symbols in Alignments
#
# Rosalind link: [Isolating Symbols in Alignments](http://rosalind.info/problems/osym/)

# %%
# TODO

# %% [markdown]
# ### Pairwise Global Alignment
#
# Rosalind link: [Pairwise Global Alignment](http://rosalind.info/problems/need/)

# %%
# TODO

# %% [markdown]
# ### Suboptimal Local Alignment
#
# Rosalind link: [Suboptimal Local Alignment](http://rosalind.info/problems/subo/)

# %%
# TODO

# %% [markdown]
# ### Global Multiple Alignment
#
# Rosalind link: [Global Multiple Alignment](http://rosalind.info/problems/clus/)

# %%
# TODO
