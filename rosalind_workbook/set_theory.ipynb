# %% [markdown]
# # Set Theory
#
# The mathematical study of sets and their properties.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/set-theory.jpg?v=1526042457">
#
# Rosalind link: [Set Theory](http://rosalind.info/problems/topics/set-theory/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Counting Subsets
#
# Rosalind link: [Counting Subsets](http://rosalind.info/problems/sset/)

# %%
# TODO

# %% [markdown]
# ### Introduction to Set Operations
#
# Rosalind link: [Introduction to Set Operations](http://rosalind.info/problems/seto/)

# %%
# TODO

# %% [markdown]
# ### Creating a Restriction Map
#
# Rosalind link: [Creating a Restriction Map](http://rosalind.info/problems/pdpl/)

# %%
# TODO
