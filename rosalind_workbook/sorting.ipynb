# %% [markdown]
# # Sorting
#
# The problem of finding a smallest collection of operations that changes a structure into a nicely ordered one.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/sorting.jpg?v=1526042457">
#
# Rosalind link: [Sorting](http://rosalind.info/problems/topics/sorting/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Insertion Sort
#
# Rosalind link: [Insertion Sort](http://rosalind.info/problems/ins/)

# %%
# TODO

# %% [markdown]
# ### Majority Element
#
# Rosalind link: [Majority Element](http://rosalind.info/problems/maj/)

# %%
# TODO

# %% [markdown]
# ### Merge Two Sorted Arrays
#
# Rosalind link: [Merge Two Sorted Arrays](http://rosalind.info/problems/mer/)

# %%
# TODO

# %% [markdown]
# ### 2SUM
#
# Rosalind link: [2SUM](http://rosalind.info/problems/2sum/)

# %%
# TODO

# %% [markdown]
# ### Building a Heap
#
# Rosalind link: [Building a Heap](http://rosalind.info/problems/hea/)

# %%
# TODO

# %% [markdown]
# ### Merge Sort
#
# Rosalind link: [Merge Sort](http://rosalind.info/problems/ms/)

# %%
# TODO

# %% [markdown]
# ### 2-Way Partition
#
# Rosalind link: [2-Way Partition](http://rosalind.info/problems/par/)

# %%
# TODO

# %% [markdown]
# ### 3SUM
#
# Rosalind link: [3SUM](http://rosalind.info/problems/3sum/)

# %%
# TODO

# %% [markdown]
# ### Heap Sort
#
# Rosalind link: [Heap Sort](http://rosalind.info/problems/hs/)

# %%
# TODO

# %% [markdown]
# ### Counting Inversions
#
# Rosalind link: [Counting Inversions](http://rosalind.info/problems/inv/)

# %%
# TODO

# %% [markdown]
# ### 3-Way Partition
#
# Rosalind link: [3-Way Partition](http://rosalind.info/problems/par3/)

# %%
# TODO

# %% [markdown]
# ### Median
#
# Rosalind link: [Median](http://rosalind.info/problems/med/)

# %%
# TODO

# %% [markdown]
# ### Partial Sort
#
# Rosalind link: [Partial Sort](http://rosalind.info/problems/ps/)

# %%
# TODO

# %% [markdown]
# ### Quick Sort
#
# Rosalind link: [Quick Sort](http://rosalind.info/problems/qs/)

# %%
# TODO
