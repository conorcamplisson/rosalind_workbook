# %% [markdown]
# # Combinatorics
#
# The mathematics of counting objects.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/combinatorics.jpg?v=1526042457">
#
# Rosalind link: [Combinatorics](http://rosalind.info/problems/topics/combinatorics/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Rabbits and Recurrence Relations
#
# Rosalind link: [Rabbits and Recurrence Relations](http://rosalind.info/problems/fib/)

# %%
# TODO

# %% [markdown]
# ### Mortal Fibonacci Rabbits
#
# Rosalind link: [Mortal Fibonacci Rabbits](http://rosalind.info/problems/fibd/)

# %%
# TODO

# %% [markdown]
# ### Inferring mRNA from Protein
#
# Rosalind link: [Inferring mRNA from Protein](http://rosalind.info/problems/mrna/)

# %%
# TODO

# %% [markdown]
# ### Open Reading Frames
#
# Rosalind link: [Open Reading Frames](http://rosalind.info/problems/orf/)

# %%
# TODO

# %% [markdown]
# ### Enumerating Gene Orders
#
# Rosalind link: [Enumerating Gene Orders](http://rosalind.info/problems/perm/)

# %%
# TODO

# %% [markdown]
# ### Perfect Matchings and RNA Secondary Structures
#
# Rosalind link: [Perfect Matchings and RNA Secondary Structures](http://rosalind.info/problems/pmch/)

# %%
# TODO

# %% [markdown]
# ### Partial Permutations
#
# Rosalind link: [Partial Permutations](http://rosalind.info/problems/pper/)

# %%
# TODO

# %% [markdown]
# ### Enumerating Oriented Gene Orderings
#
# Rosalind link: [Enumerating Oriented Gene Orderings](http://rosalind.info/problems/sign/)

# %%
# TODO

# %% [markdown]
# ### Catalan Numbers and RNA Secondary Structures
#
# Rosalind link: [Catalan Numbers and RNA Secondary Structures](http://rosalind.info/problems/cat/)

# %%
# TODO

# %% [markdown]
# ### Counting Phylogenetic Ancestors
#
# Rosalind link: [Counting Phylogenetic Ancestors](http://rosalind.info/problems/inod/)

# %%
# TODO

# %% [markdown]
# ### Maximum Matchings and RNA Secondary Structures
#
# Rosalind link: [Maximum Matchings and RNA Secondary Structures](http://rosalind.info/problems/mmch/)

# %%
# TODO

# %% [markdown]
# ### Reversal Distance
#
# Rosalind link: [Reversal Distance](http://rosalind.info/problems/rear/)

# %%
# TODO

# %% [markdown]
# ### Counting Subsets
#
# Rosalind link: [Counting Subsets](http://rosalind.info/problems/sset/)

# %%
# TODO

# %% [markdown]
# ### Introduction to Alternative Splicing
#
# Rosalind link: [Introduction to Alternative Splicing](http://rosalind.info/problems/aspc/)

# %%
# TODO

# %% [markdown]
# ### Motzkin Numbers and RNA Secondary Structures
#
# Rosalind link: [Motzkin Numbers and RNA Secondary Structures](http://rosalind.info/problems/motz/)

# %%
# TODO

# %% [markdown]
# ### Sorting by Reversals
#
# Rosalind link: [Sorting by Reversals](http://rosalind.info/problems/sort/)

# %%
# TODO

# %% [markdown]
# ### Wobble Bonding and RNA Secondary Structures
#
# Rosalind link: [Wobble Bonding and RNA Secondary Structures](http://rosalind.info/problems/rnas/)

# %%
# TODO

# %% [markdown]
# ### Counting Optimal Alignments
#
# Rosalind link: [Counting Optimal Alignments](http://rosalind.info/problems/ctea/)

# %%
# TODO

# %% [markdown]
# ### Counting Unrooted Binary Trees
#
# Rosalind link: [Counting Unrooted Binary Trees](http://rosalind.info/problems/cunr/)

# %%
# TODO

# %% [markdown]
# ### Counting Quartets
#
# Rosalind link: [Counting Quartets](http://rosalind.info/problems/cntq/)

# %%
# TODO

# %% [markdown]
# ### Enumerating Unrooted Binary Trees
#
# Rosalind link: [Enumerating Unrooted Binary Trees](http://rosalind.info/problems/eubt/)

# %%
# TODO

# %% [markdown]
# ### Counting Rooted Binary Trees
#
# Rosalind link: [Counting Rooted Binary Trees](http://rosalind.info/problems/root/)

# %%
# TODO
