# %% [markdown]
# # Graph Algorithms
#
# An algorithm requiring the interpretation and manipulation of networks, or graphs.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/graph-algorithms.jpg?v=1526042457">
#
# Rosalind link: [Graph Algorithms](http://rosalind.info/problems/topics/graph-algorithms/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Overlap Graphs
#
# Rosalind link: [Overlap Graphs](http://rosalind.info/problems/grph/)

# %%
# TODO

# %% [markdown]
# ### Completing a Tree
#
# Rosalind link: [Completing a Tree](http://rosalind.info/problems/tree/)

# %%
# TODO

# %% [markdown]
# ### Introduction to Pattern Matching
#
# Rosalind link: [Introduction to Pattern Matching](http://rosalind.info/problems/trie/)

# %%
# TODO

# %% [markdown]
# ### Finding the Longest Multiple Repeat
#
# Rosalind link: [Finding the Longest Multiple Repeat](http://rosalind.info/problems/lrep/)

# %%
# TODO

# %% [markdown]
# ### Wobble Bonding and RNA Secondary Structures
#
# Rosalind link: [Wobble Bonding and RNA Secondary Structures](http://rosalind.info/problems/rnas/)

# %%
# TODO

# %% [markdown]
# ### Genome Assembly with Perfect Coverage
#
# Rosalind link: [Genome Assembly with Perfect Coverage](http://rosalind.info/problems/pcov/)

# %%
# TODO

# %% [markdown]
# ### Using the Spectrum Graph to Infer Peptides
#
# Rosalind link: [Using the Spectrum Graph to Infer Peptides](http://rosalind.info/problems/sgra/)

# %%
# TODO

# %% [markdown]
# ### Encoding Suffix Trees
#
# Rosalind link: [Encoding Suffix Trees](http://rosalind.info/problems/suff/)

# %%
# TODO

# %% [markdown]
# ### Genome Assembly Using Reads
#
# Rosalind link: [Genome Assembly Using Reads](http://rosalind.info/problems/gasm/)

# %%
# TODO

# %% [markdown]
# ### Identifying Maximal Repeats
#
# Rosalind link: [Identifying Maximal Repeats](http://rosalind.info/problems/mrep/)

# %%
# TODO

# %% [markdown]
# ### Genome Assembly with Perfect Coverage and Repeats
#
# Rosalind link: [Genome Assembly with Perfect Coverage and Repeats](http://rosalind.info/problems/grep/)

# %%
# TODO
