# %% [markdown]
# # Phylogeny
#
# A tree modeling the evolutionary scenario deriving a collection of taxa from their proposed ancestors.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/phylogeny.jpg?v=1526042457">
#
# Rosalind link: [Phylogeny](http://rosalind.info/problems/topics/phylogeny/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Completing a Tree
#
# Rosalind link: [Completing a Tree](http://rosalind.info/problems/tree/)

# %%
# TODO

# %% [markdown]
# ### Counting Phylogenetic Ancestors
#
# Rosalind link: [Counting Phylogenetic Ancestors](http://rosalind.info/problems/inod/)

# %%
# TODO

# %% [markdown]
# ### Creating a Distance Matrix
#
# Rosalind link: [Creating a Distance Matrix](http://rosalind.info/problems/pdst/)

# %%
# TODO

# %% [markdown]
# ### Distances in Trees
#
# Rosalind link: [Distances in Trees](http://rosalind.info/problems/nwck/)

# %%
# TODO

# %% [markdown]
# ### Creating a Character Table
#
# Rosalind link: [Creating a Character Table](http://rosalind.info/problems/ctbl/)

# %%
# TODO

# %% [markdown]
# ### Newick Format with Edge Weights
#
# Rosalind link: [Newick Format with Edge Weights](http://rosalind.info/problems/nkew/)

# %%
# TODO

# %% [markdown]
# ### Creating a Character Table from Genetic Strings
#
# Rosalind link: [Creating a Character Table from Genetic Strings](http://rosalind.info/problems/cstr/)

# %%
# TODO

# %% [markdown]
# ### Counting Unrooted Binary Trees
#
# Rosalind link: [Counting Unrooted Binary Trees](http://rosalind.info/problems/cunr/)

# %%
# TODO

# %% [markdown]
# ### Quartets
#
# Rosalind link: [Quartets](http://rosalind.info/problems/qrt/)

# %%
# TODO

# %% [markdown]
# ### Character-Based Phylogeny
#
# Rosalind link: [Character-Based Phylogeny](http://rosalind.info/problems/chbp/)

# %%
# TODO

# %% [markdown]
# ### Counting Quartets
#
# Rosalind link: [Counting Quartets](http://rosalind.info/problems/cntq/)

# %%
# TODO

# %% [markdown]
# ### Enumerating Unrooted Binary Trees
#
# Rosalind link: [Enumerating Unrooted Binary Trees](http://rosalind.info/problems/eubt/)

# %%
# TODO

# %% [markdown]
# ### Inferring Genotype from a Pedigree
#
# Rosalind link: [Inferring Genotype from a Pedigree](http://rosalind.info/problems/mend/)

# %%
# TODO

# %% [markdown]
# ### Counting Rooted Binary Trees
#
# Rosalind link: [Counting Rooted Binary Trees](http://rosalind.info/problems/root/)

# %%
# TODO

# %% [markdown]
# ### Phylogeny Comparison with Split Distance
#
# Rosalind link: [Phylogeny Comparison with Split Distance](http://rosalind.info/problems/sptd/)

# %%
# TODO

# %% [markdown]
# ### Alignment-Based Phylogeny
#
# Rosalind link: [Alignment-Based Phylogeny](http://rosalind.info/problems/alph/)

# %%
# TODO

# %% [markdown]
# ### Fixing an Inconsistent Character Set
#
# Rosalind link: [Fixing an Inconsistent Character Set](http://rosalind.info/problems/cset/)

# %%
# TODO

# %% [markdown]
# ### Quartet Distance
#
# Rosalind link: [Quartet Distance](http://rosalind.info/problems/qrtd/)

# %%
# TODO

# %% [markdown]
# ### Identifying Reversing Substitutions
#
# Rosalind link: [Identifying Reversing Substitutions](http://rosalind.info/problems/rsub/)

# %%
# TODO
