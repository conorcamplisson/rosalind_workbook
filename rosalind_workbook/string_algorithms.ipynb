# %% [markdown]
# # String Algorithms
#
# An algorithm involving the manipulation and properties of chains of symbols.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/string-algorithms.jpg?v=1526042457">
#
# Rosalind link: [String Algorithms](http://rosalind.info/problems/topics/string-algorithms/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Counting DNA Nucleotides
#
# Rosalind link: [Counting DNA Nucleotides](http://rosalind.info/problems/dna/)

# %%
# TODO

# %% [markdown]
# ### Transcribing DNA into RNA
#
# Rosalind link: [Transcribing DNA into RNA](http://rosalind.info/problems/rna/)

# %%
# TODO

# %% [markdown]
# ### Complementing a Strand of DNA
#
# Rosalind link: [Complementing a Strand of DNA](http://rosalind.info/problems/revc/)

# %%
# TODO

# %% [markdown]
# ### Computing GC Content
#
# Rosalind link: [Computing GC Content](http://rosalind.info/problems/gc/)

# %%
# TODO

# %% [markdown]
# ### Finding a Motif in DNA
#
# Rosalind link: [Finding a Motif in DNA](http://rosalind.info/problems/subs/)

# %%
# TODO

# %% [markdown]
# ### Consensus and Profile
#
# Rosalind link: [Consensus and Profile](http://rosalind.info/problems/cons/)

# %%
# TODO

# %% [markdown]
# ### Finding a Shared Motif
#
# Rosalind link: [Finding a Shared Motif](http://rosalind.info/problems/lcsm/)

# %%
# TODO

# %% [markdown]
# ### Locating Restriction Sites
#
# Rosalind link: [Locating Restriction Sites](http://rosalind.info/problems/revp/)

# %%
# TODO

# %% [markdown]
# ### RNA Splicing
#
# Rosalind link: [RNA Splicing](http://rosalind.info/problems/splc/)

# %%
# TODO

# %% [markdown]
# ### Enumerating k-mers Lexicographically
#
# Rosalind link: [Enumerating k-mers Lexicographically](http://rosalind.info/problems/lexf/)

# %%
# TODO

# %% [markdown]
# ### Perfect Matchings and RNA Secondary Structures
#
# Rosalind link: [Perfect Matchings and RNA Secondary Structures](http://rosalind.info/problems/pmch/)

# %%
# TODO

# %% [markdown]
# ### Finding a Spliced Motif
#
# Rosalind link: [Finding a Spliced Motif](http://rosalind.info/problems/sseq/)

# %%
# TODO

# %% [markdown]
# ### Catalan Numbers and RNA Secondary Structures
#
# Rosalind link: [Catalan Numbers and RNA Secondary Structures](http://rosalind.info/problems/cat/)

# %%
# TODO

# %% [markdown]
# ### k-Mer Composition
#
# Rosalind link: [k-Mer Composition](http://rosalind.info/problems/kmer/)

# %%
# TODO

# %% [markdown]
# ### Speeding Up Motif Finding
#
# Rosalind link: [Speeding Up Motif Finding](http://rosalind.info/problems/kmp/)

# %%
# TODO

# %% [markdown]
# ### Finding a Shared Spliced Motif
#
# Rosalind link: [Finding a Shared Spliced Motif](http://rosalind.info/problems/lcsq/)

# %%
# TODO

# %% [markdown]
# ### Ordering Strings of Varying Length Lexicographically
#
# Rosalind link: [Ordering Strings of Varying Length Lexicographically](http://rosalind.info/problems/lexv/)

# %%
# TODO

# %% [markdown]
# ### Maximum Matchings and RNA Secondary Structures
#
# Rosalind link: [Maximum Matchings and RNA Secondary Structures](http://rosalind.info/problems/mmch/)

# %%
# TODO

# %% [markdown]
# ### Motzkin Numbers and RNA Secondary Structures
#
# Rosalind link: [Motzkin Numbers and RNA Secondary Structures](http://rosalind.info/problems/motz/)

# %%
# TODO

# %% [markdown]
# ### Interleaving Two Motifs
#
# Rosalind link: [Interleaving Two Motifs](http://rosalind.info/problems/scsp/)

# %%
# TODO

# %% [markdown]
# ### Introduction to Pattern Matching
#
# Rosalind link: [Introduction to Pattern Matching](http://rosalind.info/problems/trie/)

# %%
# TODO

# %% [markdown]
# ### Finding Disjoint Motifs in a Gene
#
# Rosalind link: [Finding Disjoint Motifs in a Gene](http://rosalind.info/problems/itwv/)

# %%
# TODO

# %% [markdown]
# ### Encoding Suffix Trees
#
# Rosalind link: [Encoding Suffix Trees](http://rosalind.info/problems/suff/)

# %%
# TODO

# %% [markdown]
# ### Linguistic Complexity of a Genome
#
# Rosalind link: [Linguistic Complexity of a Genome](http://rosalind.info/problems/ling/)

# %%
# TODO

# %% [markdown]
# ### Identifying Maximal Repeats
#
# Rosalind link: [Identifying Maximal Repeats](http://rosalind.info/problems/mrep/)

# %%
# TODO

# %% [markdown]
# ### Finding All Similar Motifs
#
# Rosalind link: [Finding All Similar Motifs](http://rosalind.info/problems/ksim/)

# %%
# TODO
