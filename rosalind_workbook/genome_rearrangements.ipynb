# %% [markdown]
# # Genome Rearrangements
#
# A large-scale mutation that affects the makeup of entire intervals of nucleic acid.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/genome-rearrangements.jpg?v=1526042457">
#
# Rosalind link: [Genome Rearrangements](http://rosalind.info/problems/topics/genome-rearrangements/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Enumerating Gene Orders
#
# Rosalind link: [Enumerating Gene Orders](http://rosalind.info/problems/perm/)

# %%
# TODO

# %% [markdown]
# ### Longest Increasing Subsequence
#
# Rosalind link: [Longest Increasing Subsequence](http://rosalind.info/problems/lgis/)

# %%
# TODO

# %% [markdown]
# ### Partial Permutations
#
# Rosalind link: [Partial Permutations](http://rosalind.info/problems/pper/)

# %%
# TODO

# %% [markdown]
# ### Enumerating Oriented Gene Orderings
#
# Rosalind link: [Enumerating Oriented Gene Orderings](http://rosalind.info/problems/sign/)

# %%
# TODO

# %% [markdown]
# ### Reversal Distance
#
# Rosalind link: [Reversal Distance](http://rosalind.info/problems/rear/)

# %%
# TODO

# %% [markdown]
# ### Sorting by Reversals
#
# Rosalind link: [Sorting by Reversals](http://rosalind.info/problems/sort/)

# %%
# TODO
