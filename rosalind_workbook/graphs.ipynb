# %% [markdown]
# # Graphs
#
# A network containing a collection of nodes, pairs of which are joined by edges.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/graphs.jpg?v=1526042457">
#
# Rosalind link: [Graphs](http://rosalind.info/problems/topics/graphs/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Degree Array
#
# Rosalind link: [Degree Array](http://rosalind.info/problems/deg/)

# %%
# TODO

# %% [markdown]
# ### Double-Degree Array
#
# Rosalind link: [Double-Degree Array](http://rosalind.info/problems/ddeg/)

# %%
# TODO

# %% [markdown]
# ### Breadth-First Search
#
# Rosalind link: [Breadth-First Search](http://rosalind.info/problems/bfs/)

# %%
# TODO

# %% [markdown]
# ### Connected Components
#
# Rosalind link: [Connected Components](http://rosalind.info/problems/cc/)

# %%
# TODO

# %% [markdown]
# ### Testing Bipartiteness
#
# Rosalind link: [Testing Bipartiteness](http://rosalind.info/problems/bip/)

# %%
# TODO

# %% [markdown]
# ### Testing Acyclicity
#
# Rosalind link: [Testing Acyclicity](http://rosalind.info/problems/dag/)

# %%
# TODO

# %% [markdown]
# ### Dijkstra's Algorithm
#
# Rosalind link: [Dijkstra's Algorithm](http://rosalind.info/problems/dij/)

# %%
# TODO

# %% [markdown]
# ### Square in a Graph
#
# Rosalind link: [Square in a Graph](http://rosalind.info/problems/sq/)

# %%
# TODO

# %% [markdown]
# ### Bellman-Ford Algorithm
#
# Rosalind link: [Bellman-Ford Algorithm](http://rosalind.info/problems/bf/)

# %%
# TODO

# %% [markdown]
# ### Shortest Cycle Through a Given Edge
#
# Rosalind link: [Shortest Cycle Through a Given Edge](http://rosalind.info/problems/cte/)

# %%
# TODO

# %% [markdown]
# ### Topological Sorting
#
# Rosalind link: [Topological Sorting](http://rosalind.info/problems/ts/)

# %%
# TODO

# %% [markdown]
# ### Hamiltonian Path in DAG
#
# Rosalind link: [Hamiltonian Path in DAG](http://rosalind.info/problems/hdag/)

# %%
# TODO

# %% [markdown]
# ### Negative Weight Cycle
#
# Rosalind link: [Negative Weight Cycle](http://rosalind.info/problems/nwc/)

# %%
# TODO

# %% [markdown]
# ### Strongly Connected Components
#
# Rosalind link: [Strongly Connected Components](http://rosalind.info/problems/scc/)

# %%
# TODO

# %% [markdown]
# ### 2-Satisfiability
#
# Rosalind link: [2-Satisfiability](http://rosalind.info/problems/2sat/)

# %%
# TODO

# %% [markdown]
# ### General Sink
#
# Rosalind link: [General Sink](http://rosalind.info/problems/gs/)

# %%
# TODO

# %% [markdown]
# ### Semi-Connected Graph
#
# Rosalind link: [Semi-Connected Graph](http://rosalind.info/problems/sc/)

# %%
# TODO

# %% [markdown]
# ### Shortest Paths in DAG
#
# Rosalind link: [Shortest Paths in DAG](http://rosalind.info/problems/sdag/)

# %%
# TODO
