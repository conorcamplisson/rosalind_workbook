# %% [markdown]
# # Population Dynamics
#
#
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/population-dynamics.jpg?v=1526042457">
#
# Rosalind link: [Population Dynamics](http://rosalind.info/problems/topics/population-dynamics/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Counting Disease Carriers
#
# Rosalind link: [Counting Disease Carriers](http://rosalind.info/problems/afrq/)

# %%
# TODO

# %% [markdown]
# ### The Wright-Fisher Model of Genetic Drift
#
# Rosalind link: [The Wright-Fisher Model of Genetic Drift](http://rosalind.info/problems/wfmd/)

# %%
# TODO

# %% [markdown]
# ### The Founder Effect and Genetic Drift
#
# Rosalind link: [The Founder Effect and Genetic Drift](http://rosalind.info/problems/foun/)

# %%
# TODO
