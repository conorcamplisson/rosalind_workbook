# %% [markdown]
# # Computational Mass Spectrometry
#
# A technique used to identify molecules by splitting them into pieces and analyzing chemical properties of these small pieces.
#
# <img style="margin-left: 0px" src="http://rosalind.info/static/img/topics/pictures/computational-mass-spectrometry.jpg?v=1526042457">
#
# Rosalind link: [Computational Mass Spectrometry](http://rosalind.info/problems/topics/computational-mass-spectrometry/)
#
# ### Import modules

# %%
import os
import sys
from itertools import permutations
import numpy as np
import pandas as pd
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import generic_rna

print('DONE!')

# %% [markdown]
# ### Calculating Protein Mass
#
# Rosalind link: [Calculating Protein Mass](http://rosalind.info/problems/prtm/)

# %%
# TODO

# %% [markdown]
# ### Inferring Protein from Spectrum
#
# Rosalind link: [Inferring Protein from Spectrum](http://rosalind.info/problems/spec/)

# %%
# TODO

# %% [markdown]
# ### Comparing Spectra with the Spectral Convolution
#
# Rosalind link: [Comparing Spectra with the Spectral Convolution](http://rosalind.info/problems/conv/)

# %%
# TODO

# %% [markdown]
# ### Inferring Peptide from Full Spectrum
#
# Rosalind link: [Inferring Peptide from Full Spectrum](http://rosalind.info/problems/full/)

# %%
# TODO

# %% [markdown]
# ### Matching a Spectrum to a Protein
#
# Rosalind link: [Matching a Spectrum to a Protein](http://rosalind.info/problems/prsm/)

# %%
# TODO

# %% [markdown]
# ### Using the Spectrum Graph to Infer Peptides
#
# Rosalind link: [Using the Spectrum Graph to Infer Peptides](http://rosalind.info/problems/sgra/)

# %%
# TODO
